# %%
import matplotlib.pyplot as plt
from pandas.core.common import flatten
import copy
import numpy as np
import random

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import albumentations as A
from albumentations.pytorch import ToTensorV2
import cv2

import glob
from tqdm import tqdm
import pickle
from natsort import natsorted, ns

f = open('/Users/mohamad/python-workspace/lab/extract_img/labels.plk', 'rb')
labels_p = pickle.load(f)   
transform = T.Compose([
                       T.ToTensor(),
                      T.Resize(36)])

####################################################
#       Create Train, Valid and Test sets
####################################################
# train_data_path = '/Users/mohamad/python-workspace/lab/extract_img/tr_pic2/train' 
# test_data_path = '/Users/mohamad/python-workspace/lab/extract_img/tr_pic2/test' 
all_data_path = '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center' 
all_folder_paths = [] #to store image paths in list

#1.
# get all the paths from train_data_path and append image paths and class to to respective lists
# eg. train path-> 'images/train/26.Pont_du_Gard/4321ee6695c23c7b.jpg'
# eg. class -> 26.Pont_du_Gard
for data_path in glob.glob(all_data_path + '/*'):
    all_folder_paths.append(data_path)
    

# print('train_image_path example: ', train_folder_paths)


#2.
# split train valid from train paths (80,20)
train_folder_paths, test_folder_paths = all_folder_paths[:int(0.9*len(all_folder_paths))], all_folder_paths[int(0.9*len(all_folder_paths)):] 
# train_folder_paths, val_folder_paths = train_folder_paths[:int(0.9*len(train_folder_paths))], train_folder_paths[int(0.9*len(train_folder_paths)):] 
#3.
# create the test_image_paths
# test_folder_paths = []
# for data_path in glob.glob(test_data_path + '/*'):
#     test_folder_paths.append(data_path)


test_folder_paths=natsorted(test_folder_paths, key=lambda y: y.lower())
train_folder_paths =natsorted(train_folder_paths, key=lambda y: y.lower())
# val_folder_paths=natsorted(val_folder_paths, key=lambda y: y.lower())
# print("Train size: {}\nValid size: {}\nTest size: {}".format(len(train_folder_paths), len(valid_image_paths), len(test_image_paths)))
seq_l=6
def imagesToSeq(seq_l,fol_path):
    
    image_seq = np.empty((0,seq_l))
    for fol in fol_path:
        image_paths=natsorted((glob.glob(fol + '/*')), key=lambda y: y.lower())
#         print(fol)
        im_list=[]
        for i in range(len(image_paths)-seq_l+1):
            im_list2=[]
            for j in range(seq_l):
                im_list2.append(image_paths[i+j])
                
            im_list.append(im_list2)
#             print(im_list)
            
        
        im_list=np.asarray(im_list).reshape( (len(image_paths)-seq_l+1),seq_l)
        
        
#         image_seq=np.append(image_seq,im_list)
#         print(image_seq)
#         image_seq = im_list
        image_seq=np.vstack((im_list,image_seq))
        
#     print(image_seq.shape)   
#         image_seq=np.asarray(image_seq)
        
#     image_seq= image_seq.reshape(int(image_seq.shape[0]/seq_l),seq_l)
    print(image_seq) 
    return image_seq
    
    
train_seq=imagesToSeq(seq_l,train_folder_paths)        
test_seq=imagesToSeq(seq_l,test_folder_paths)             
val_seq = imagesToSeq(seq_l,val_folder_paths)   
class imgDataset(Dataset):
    def __init__(self, seq_paths,seq_len, transform=False):
        self.seq_paths = seq_paths
        self.transform = transform
        self.seq_len = seq_len
        
    def __len__(self):
        return len(self.seq_paths)

    def __getitem__(self, idx):
        images=[]
        labels=[]
        sq=self.seq_paths[idx]
        
        for i in range(self.seq_len):
            
            image_filepath = sq[i]
            
            image = cv2.imread(image_filepath)
            image = self.transform(image)
            images.append(image)

            indx=int(image_filepath.split('/')[-1].split('.')[-2])
            row=int(image_filepath.split('/')[-2])   
            label=(labels_p[row][indx])/10
            labels.append(torch.tensor(label))
            

        # label = image_filepath.split('/')[-2]
        # label = class_to_idx[label]

        images = torch.stack(images)
        labels = torch.stack(labels)
        
        return images, labels 
    
#######################################################
#                  Create Dataset
#######################################################

train_dataset = imgDataset(train_seq,seq_l, transform)
# valid_dataset = imgDataset(val_seq,seq_l, transform) #test transforms are applied
test_dataset = imgDataset(test_seq,seq_l, transform)


# print(test_dataset[0])

#######################################################
#                  Define Dataloaders
#######################################################
batch_size = 16
train_dl = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True
)

# valid_dl = DataLoader(
#     valid_dataset, batch_size=batch_size, shuffle=False
# )


test_dl = DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False
)

print(batch_size)
# Out:
# [['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/58/7.jpg']
#  ...
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/1/9.jpg']]
# [['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/9.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/9.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/22/10.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/9.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/9.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/10.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/9.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/10.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/14/11.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/9.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/9.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/13/10.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/9.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/9.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/5/10.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/2/8.jpg']]
# [['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49/9.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47/9.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40/9.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/0.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/5.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/1.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/6.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/2.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/7.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/3.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/8.jpg']
#  ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/4.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/5.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/6.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/7.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/8.jpg'
#   '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3/9.jpg']]
# 16

# %%
val_folder_paths
# Out:
# ['/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/3',
#  '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/12',
#  '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/40',
#  '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/47',
#  '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/find center/49']

# %%
for images, labels in valid_dl:
    break
print(labels)
# Out:
# tensor([[24.2000, 36.7000, 44.5000, 48.9000, 50.8000, 50.3000],
#         [36.7000, 44.5000, 48.9000, 50.8000, 50.3000, 47.5000],
#         [44.5000, 48.9000, 50.8000, 50.3000, 47.5000, 42.2000],
#         [48.9000, 50.8000, 50.3000, 47.5000, 42.2000, 33.7000],
#         [50.8000, 50.3000, 47.5000, 42.2000, 33.7000, 20.6000],
#         [22.8000, 35.1000, 43.2000, 47.9000, 49.8000, 49.2000],
#         [35.1000, 43.2000, 47.9000, 49.8000, 49.2000, 45.7000],
#         [43.2000, 47.9000, 49.8000, 49.2000, 45.7000, 38.9000],
#         [47.9000, 49.8000, 49.2000, 45.7000, 38.9000, 27.4000],
#         [49.8000, 49.2000, 45.7000, 38.9000, 27.4000, 15.8000],
#         [25.6000, 37.1000, 44.3000, 48.2000, 49.4000, 47.8000],
#         [37.1000, 44.3000, 48.2000, 49.4000, 47.8000, 43.1000],
#         [44.3000, 48.2000, 49.4000, 47.8000, 43.1000, 34.5000],
#         [48.2000, 49.4000, 47.8000, 43.1000, 34.5000, 22.6000],
#         [49.4000, 47.8000, 43.1000, 34.5000, 22.6000, 18.9000],
#         [17.1000, 28.7000, 35.9000, 39.8000, 40.6000, 38.4000]])

# %%
# Load in relevant libraries, and alias where appropriate
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

# Define relevant variables for the ML task

num_classes = 64
learning_rate = 0.001
num_epochs = 20

# Device will determine whether to run the training on GPU or CPU.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
#Defining the convolutional neural network
class LeNet5(nn.Module):
    def __init__(self, num_classes):
        super(LeNet5, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 6, kernel_size=5, stride=1, padding=0),
            nn.BatchNorm2d(6),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 5, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(6, 12, kernel_size=5, stride=1, padding=0),
            nn.BatchNorm2d(12),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.fc = nn.Linear(720, 128)
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(128, 32)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(32, 1)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
#         print(out.size())
        out = self.fc(out)
        out = self.relu(out)
        out = self.fc1(out)
        out = self.relu1(out)
        out = self.fc2(out)
        return out

# %%
model = LeNet5(num_classes).to(device)

#Setting the loss function

cost = nn.L1Loss()
#Setting the optimizer with the model parameters and learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

#this is defined to print how many steps are remaining when training
total_step = len(train_dl)

# %%
def yhat(seq_l,f):
    aa = -240
    d_t = 0.1
    one = torch.ones(seq_l)
    a_t = torch.arange(1,seq_l+1)*d_t
    A = torch.t(torch.vstack((a_t,one)))
    # np.dot(A.T,A)
    a = a_t**2*aa
    
#     y_h = a + np.dot(np.dot(A,(np.linalg.inv(np.dot(A.T,A)))),A.T)*(f-a)
    y_hh = a + A@(torch.linalg.inv(torch.t(A)@A))@torch.t(A)@(f-a)
    return y_hh

# %%
num_epochs = 100
requires_grad=False
total_step = len(train_dl)

t_loss = []
val_losses=[]
def validate(model, data):
    l1= nn.L1Loss()
    for i, (images, labels) in enumerate(data):
        
        
        images = images.to(device)
        images = torch.reshape(images,(images.shape[0]*seq_l,3,64,36))
        labels = labels.to(device)
        x = model(images)
        labels = torch.flatten(labels)
#         print(x.size(),labels.size())
        loss1 = l1(x,labels.to(torch.float))
#         print(loss1)
        
    return loss1

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_dl):  
        
        
        images = images.to(device)
        images = torch.reshape(images,(images.shape[0]*seq_l,3,64,36))
        labels = labels.to(device).to(torch.long)
#         print(labels.size())
        labels = torch.flatten(labels)
        #Forward pass
        out = model(images)
#         if dummy ==1:
#             out.data = torch.reshape(torch.tensor([64,64,64,64,64]).to(torch.float),(5,1))
#             dummy = 0
#         print(out)
#         _, out = torch.max(torch.absolute(out), 1)
#         print(out)
        out=torch.reshape(out,(int(images.shape[0]/seq_l),seq_l))
    
#         print(out.size())
        loss_v =[]
        yh_v=[]
        yh_v = torch.tensor(yh_v)
        for i in range(int(images.shape[0]/seq_l)):
        
            yh=yhat(seq_l,(out[i]))
            yh_v=torch.cat((yh_v,yh),0)
#             print(yh)
#             loss_v.append(cost( out[i],yh))
            
#             loss_v.append(cost(out[i].to(torch.float),labels[i]))
#         print(out.size())
#         print(yh_v.size())
        yh_v=torch.reshape(yh_v,(int(images.shape[0]/seq_l),seq_l))
        loss = cost(out,yh_v)
#         val_loss=(validate(model, valid_dl))
        
#         loss=sum(loss_v)/batch_size
#         loss = loss.clone().detach().requires_grad_(True)
#         loss=torch.tensor(loss,requires_grad=True)
#         loss=cost(outputs,labels)
#         loss=torch.tensor(loss,requires_grad=True)
#         print(loss)
#         print(float(loss_v[0]))
        	
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        		
#         if (i+1) % 400 == 0:
#             print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
#         		           .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
    print("loss",epoch,"=====",float(loss) )    
    t_loss.append(float(loss))
#     val_losses.append(float(val_loss))
from matplotlib.pyplot import figure
    
figure(figsize=(20, 11), dpi=220)    
plt.plot(t_loss) 
plt.plot(val_losses)
# Out:
# loss 0 ===== 1.5536656379699707
# loss 1 ===== 1.1520715951919556
# loss 2 ===== 1.0055158138275146
# loss 3 ===== 1.3676255941390991
# loss 4 ===== 1.618445634841919
# loss 5 ===== 1.5981309413909912
# loss 6 ===== 0.9361847043037415
# loss 7 ===== 1.2023590803146362
# loss 8 ===== 1.1650089025497437
# loss 9 ===== 2.7707977294921875
# loss 10 ===== 1.2999515533447266
# loss 11 ===== 2.036681652069092
# loss 12 ===== 1.0953609943389893
# loss 13 ===== 1.6861257553100586
# loss 14 ===== 2.064080238342285
# loss 15 ===== 1.3515520095825195
# loss 16 ===== 3.422327756881714
# loss 17 ===== 1.2512645721435547
# loss 18 ===== 1.910484790802002
# loss 19 ===== 1.6247659921646118
# loss 20 ===== 1.3950042724609375
# loss 21 ===== 1.9813218116760254
# loss 22 ===== 1.200425386428833
# loss 23 ===== 1.306614637374878
# loss 24 ===== 0.759938657283783
# loss 25 ===== 0.6737096309661865
# loss 26 ===== 0.9639816284179688
# loss 27 ===== 0.9802606701850891
# loss 28 ===== 1.7783128023147583
# loss 29 ===== 0.43582338094711304
# loss 30 ===== 1.043992280960083
# loss 31 ===== 1.3856450319290161
# loss 32 ===== 1.0222899913787842
# loss 33 ===== 1.4910728931427002
# loss 34 ===== 0.6953749060630798
# loss 35 ===== 0.7113685011863708
# loss 36 ===== 1.0193992853164673
# loss 37 ===== 1.7465265989303589
# loss 38 ===== 1.1161630153656006
# loss 39 ===== 1.0477460622787476
# loss 40 ===== 1.2769145965576172
# loss 41 ===== 1.275659441947937
# loss 42 ===== 0.8428416848182678
# loss 43 ===== 1.2754369974136353
# loss 44 ===== 1.1035469770431519
# loss 45 ===== 1.0445384979248047
# loss 46 ===== 0.6130781173706055
# loss 47 ===== 1.33216392993927
# loss 48 ===== 1.5912452936172485
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1411], in <cell line: 23>()
#      21     return loss1
#      23 for epoch in range(num_epochs):
# ---> 24     for i, (images, labels) in enumerate(train_dl):
#      27         images = images.to(device)
#      28         images = torch.reshape(images,(images.shape[0]*seq_l,3,64,36))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# Input In [1397], in imgDataset.__getitem__(self, idx)
#     115 image_filepath = sq[i]
#     117 image = cv2.imread(image_filepath)
# --> 118 image = self.transform(image)
#     119 images.append(image)
#     121 indx=int(image_filepath.split('/')[-1].split('.')[-2])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/transforms.py:135, in ToTensor.__call__(self, pic)
#     127 def __call__(self, pic):
#     128     """
#     129     Args:
#     130         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     133         Tensor: Converted image.
#     134     """
# --> 135     return F.to_tensor(pic)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:149, in to_tensor(pic)
#     146 if pic.ndim == 2:
#     147     pic = pic[:, :, None]
# --> 149 img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
#     150 # backward compatibility
#     151 if isinstance(img, torch.ByteTensor):
#
# KeyboardInterrupt:

# %%
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
pred = []
pred = torch.tensor(pred)
targets = []
targets = torch.tensor(targets)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_dl:
        images = images.to(device)
        images = torch.reshape(images,(images.shape[0]*seq_l,3,64,36))
        labels = labels.to(device).to(torch.long)
        labels = torch.flatten(labels)

        targets = torch.cat((targets,labels),0)

        outputs = model(images)

        
        pred = torch.cat((pred,(outputs)),0)



        
from matplotlib.pyplot import figure

figure(figsize=(20, 11))
# figure.savefig('test2png.png', dpi=200)
plt.plot(targets,marker='o')
plt.plot(pred,marker='o')
plt.xlabel("Test Set")
plt.ylabel("Height")
plt.legend(["True Label","Prediction"])
plt.savefig("result_cl")
# print(pred-targets)
# print(sum(np.abs(pred-targets)))
# print(cost(targets,pred))
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
MAE_svr = mean_absolute_error(targets,pred)
err_percent = (MAE_svr/targets.mean())*100
print('error = ',100-err_percent,'%' )
print("L1 error" , MAE_svr )
L_loss = nn.L1Loss()
from sklearn.metrics import r2_score
r2 = r2_score(targets, pred)
mse = mean_squared_error(targets,pred)
print("MsE  = " , mse )


# Convert to a percentage
# Out:
# error =  tensor(84.9682) %
# L1 error 6.8023143
# MsE  =  70.94333

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(targets,pred)
# Out:
# 7.931922

# %%
outputs.size()
# Out:
# torch.Size([8, 64])

# %%
pred
# Out:
# tensor([25., 37., 45., 50., 52., 52., 48., 42., 31., 14., 22., 35., 42., 46.,
#         47., 45., 41., 34., 20., 21., 34., 41., 44., 43., 38., 27.,  7., 20.,
#         36., 45., 49., 50., 48., 40., 25.,  3., 17., 34., 42., 47., 47., 43.,
#         34., 19., 22., 40., 51., 57., 58., 58., 53., 43., 25.,  5., 20., 36.,
#         46., 50., 52., 48., 39., 22.,  3., 19., 34., 42., 47., 47., 44., 37.,
#         25.,  8.,  3., 21., 36., 44., 47., 47., 43., 36., 25., 35., 35.,  3.,
#          3.,  3.,  3.])
