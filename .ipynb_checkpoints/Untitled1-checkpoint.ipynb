# %%
import matplotlib.pyplot as plt
from pandas.core.common import flatten
import copy
import numpy as np
import random

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import albumentations as A
from albumentations.pytorch import ToTensorV2
import cv2

import glob
from tqdm import tqdm
import pickle

f = open('/Users/mohamad/python-workspace/lab/extract_img/labels.plk', 'rb')
labels = pickle.load(f)   
transform = T.Compose([
                       T.ToTensor(),
                      T.Resize(90)])
# train_transforms = A.Compose(
#     [
#         A.SmallestMaxSize(max_size=350),
#         ToTensorV2(),
#     ]
# )

# test_transforms = A.Compose(
#     [
#         A.SmallestMaxSize(max_size=350),
#         ToTensorV2(),
#     ]
# )

####################################################
#       Create Train, Valid and Test sets
####################################################
train_data_path = '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/train' 
test_data_path = '/Users/mohamad/python-workspace/lab/extract_img/tr_pic/test' 

train_image_paths = [] #to store image paths in list
classes = [] #to store class values

#1.
# get all the paths from train_data_path and append image paths and class to to respective lists
# eg. train path-> 'images/train/26.Pont_du_Gard/4321ee6695c23c7b.jpg'
# eg. class -> 26.Pont_du_Gard
for data_path in glob.glob(train_data_path + '/*'):
    classes.append(data_path.split('/')[-1]) 
    train_image_paths.append(glob.glob(data_path + '/*'))
    
train_image_paths = list(flatten(train_image_paths))
random.shuffle(train_image_paths)

print('train_image_path example: ', train_image_paths[0])
print('class example: ', classes[0])

#2.
# split train valid from train paths (80,20)
train_image_paths, valid_image_paths = train_image_paths[:int(0.8*len(train_image_paths))], train_image_paths[int(0.8*len(train_image_paths)):] 

#3.
# create the test_image_paths
test_image_paths = []
for data_path in glob.glob(test_data_path + '/*'):
    test_image_paths.append(glob.glob(data_path + '/*'))

test_image_paths = list(flatten(test_image_paths))

print("Train size: {}\nValid size: {}\nTest size: {}".format(len(train_image_paths), len(valid_image_paths), len(test_image_paths)))



import skimage.io
class imgDataset(Dataset):
    def __init__(self, image_paths, transform=False):
        self.image_paths = image_paths
        self.transform = transform
        
    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_filepath = self.image_paths[idx]
        image = cv2.imread(image_filepath)
#         image = cv2.resize(image, (90,160), interpolation = cv2.INTER_AREA)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image = cv2
        indx=int(train_image_paths[0].split('/')[-1].split('.')[-2])
        row=int(train_image_paths[0].split('/')[-2])
        label=(labels[row][indx])/4
        # label = image_filepath.split('/')[-2]
        # label = class_to_idx[label]

        image = self.transform(image)
        
        return image, label
    
#######################################################
#                  Create Dataset
#######################################################

# train_dataset = LandmarkDataset(train_image_paths,train_transforms)
# valid_dataset = LandmarkDataset(valid_image_paths,test_transforms) #test transforms are applied
# test_dataset = LandmarkDataset(test_image_paths,test_transforms)

train_dataset = imgDataset(train_image_paths, transform)
valid_dataset = imgDataset(valid_image_paths, transform) #test transforms are applied
test_dataset = imgDataset(test_image_paths, transform)

#######################################################
#                  Define Dataloaders
#######################################################
batch_size = 4
train_dl = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True
)

valid_dl = DataLoader(
    valid_dataset, batch_size=batch_size, shuffle=True
)


test_dl = DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False
)
# Out:
# train_image_path example:  /Users/mohamad/python-workspace/lab/extract_img/tr_pic/train/1/2.jpg
# class example:  32
# Train size: 422
# Valid size: 106
# Test size: 82

# %%
for i, (images, labels) in enumerate(valid_dl):
    print(images.shape)
    print(labels.shape)
# Out:
# torch.Size([4, 3, 160, 90])
# torch.Size([4])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [144], in <cell line: 1>()
# ----> 1 for i, (images, labels) in enumerate(valid_dl):
#       2     print(images.shape)
#       3     print(labels.shape)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# Input In [143], in imgDataset.__getitem__(self, idx)
#      95 indx=int(train_image_paths[0].split('/')[-1].split('.')[-2])
#      96 row=int(train_image_paths[0].split('/')[-2])
# ---> 97 label=(labels[row][indx])/4
#      98 # label = image_filepath.split('/')[-2]
#      99 # label = class_to_idx[label]
#     101 image = self.transform(image)
#
# IndexError: index 2 is out of bounds for dimension 0 with size 0

# %%
import torch, torchvision
from torch import nn
from torch import optim
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO

import copy
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np


def create_lenet():
    model = nn.Sequential(
        nn.Conv2d(3, 8, 5, padding=2),
        nn.ReLU(),
        nn.AvgPool2d(2, stride=2),
        nn.Conv2d(8, 16, 5, padding=0),
        nn.ReLU(),
        nn.AvgPool2d(2, stride=2),
        nn.Flatten(),
        nn.Linear(12160, 1024),
        nn.ReLU(),
        nn.Linear(1024, 84),
        nn.ReLU(),
        nn.Linear(84, 1)
    )
    return model


def validate(model, data):
    total = 0
    correct = 0
    for i, (images, labels) in enumerate(data):
        images = images.cpu()
        images = torch.reshape(images,(images.shape[0],3,160,90))
        
        x = model(images)
        ll = nn.CrossEntropyLoss(x,labels)
    return ll


def train(numb_epoch=3, lr=1e-3, device="cpu"):
    accuracies = []
    cnn = create_lenet().to(device)
    cec = nn.MSELoss()
    optimizer = optim.Adam(cnn.parameters(), lr=lr)
    max_accuracy = 0
    for epoch in range(numb_epoch):
        for i, (images, labels) in enumerate(train_dl):
            images = images.to(device)
            images = torch.reshape(images,(images.shape[0],3,160,90))
            
            labels = labels.to(device).to(torch.float)
            optimizer.zero_grad()
            pred = cnn(images)
            loss = cec(pred, labels)
            loss.backward()
            optimizer.step()
        accuracy = float(validate(cnn, valid_dl))
        accuracies.append(accuracy)
        if accuracy > max_accuracy:
            best_model = copy.deepcopy(cnn)
            max_accuracy = accuracy
            print("Saving Best Model with Accuracy: ", accuracy)
        print('Epoch:', epoch+1, "Accuracy :", accuracy, '%')
    plt.plot(accuracies)
    return best_model

if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")
    print("No Cuda Available")
device
# Out:
# No Cuda Available
# device(type='cpu')

# %%
lenet = train(2, device=device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [141], in <cell line: 1>()
# ----> 1 lenet = train(2, device=device)
#
# Input In [140], in train(numb_epoch, lr, device)
#      62     loss.backward()
#      63     optimizer.step()
# ---> 64 accuracy = float(validate(cnn, valid_dl))
#      65 accuracies.append(accuracy)
#      66 if accuracy > max_accuracy:
#
# Input In [140], in validate(model, data)
#      40     images = torch.reshape(images,(images.shape[0],3,160,90))
#      42     x = model(images)
# ---> 43     ll = nn.CrossEntropyLoss(x,labels)
#      44 return ll
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/loss.py:1169, in CrossEntropyLoss.__init__(self, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    1167 def __init__(self, weight: Optional[Tensor] = None, size_average=None, ignore_index: int = -100,
#    1168              reduce=None, reduction: str = 'mean', label_smoothing: float = 0.0) -> None:
# -> 1169     super(CrossEntropyLoss, self).__init__(weight, size_average, reduce, reduction)
#    1170     self.ignore_index = ignore_index
#    1171     self.label_smoothing = label_smoothing
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/loss.py:30, in _WeightedLoss.__init__(self, weight, size_average, reduce, reduction)
#      29 def __init__(self, weight: Optional[Tensor] = None, size_average=None, reduce=None, reduction: str = 'mean') -> None:
# ---> 30     super(_WeightedLoss, self).__init__(size_average, reduce, reduction)
#      31     self.register_buffer('weight', weight)
#      32     self.weight: Optional[Tensor]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/loss.py:23, in _Loss.__init__(self, size_average, reduce, reduction)
#      21 super(_Loss, self).__init__()
#      22 if size_average is not None or reduce is not None:
# ---> 23     self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
#      24 else:
#      25     self.reduction = reduction
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/_reduction.py:35, in legacy_get_string(size_average, reduce, emit_warning)
#      32 if reduce is None:
#      33     reduce = True
# ---> 35 if size_average and reduce:
#      36     ret = 'mean'
#      37 elif reduce:
#
# RuntimeError: Boolean value of Tensor with more than one value is ambiguous
